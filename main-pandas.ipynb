# %%
import tensorflow as tf
import numpy as np
import pandas as pdthe 

import matplotlib.pyplot as plt
import time

import sys
sys.path.append('./modules')
sys.path.append('./data')

from utils import *
from Bullseye import Bullseye_graph

# %load_ext autoreload
# %autoreload 2

# %%
"""
TODO:
batching : does not work with feed_dict
threshold_dim_sampling
"""
# Out:
# '\nTODO:\nbatching : does not work with feed_dict\nthreshold_dim_sampling\n'

# %%
bull = Bullseye_graph()

# %%
#"""
theta_0, x_array, y_array = generate_multilogit(d = 10,n = 10**3,k = 5)
bull.feed_with(x_array, y_array)
#"""

# %%
"""
x_array = read_idx("data/mnist/train-images.idx3-ubyte")
y_array = read_idx("data/mnist/train-labels.idx1-ubyte")
y_array = to_one_hot(y_array)

d = x_array.shape[-1]*x_array.shape[-2]
n = x_array.shape[0]
k = y_array[-1]

x_array = np.reshape(x_array, (n, d))
bull.feed_with(x_array,y_array)
# """
# Out:
# '\nx_array = read_idx("data/mnist/train-images.idx3-ubyte")\ny_array = read_idx("data/mnist/train-labels.idx1-ubyte")\ny_array = to_one_hot(y_array)\n\nd = x_array.shape[-1]*x_array.shape[-2]\nn = x_array.shape[0]\nk = y_array[-1]\n\nx_array = np.reshape(x_array, (n, d))\nbull.feed_with(x_array,y_array)\n# '

# %%
#bull.feed_with(file = "data/mnist.csv", chunksize = 10, k=10)

# %%
bull.set_model("multilogit")
bull.init_with(mu_0 = 0.5, cov_0 = 1)
options = {
    "flatten_activations" : False,
    "local_std_trick" : True,
    "m" : 0,
    "m_prior" : 0,
    "compute_kernel" : True,
    "compute_prior_kernel" : True,
    "chunk_as_sum" : True,
    "sparse" : True
}
bull.set_options(**options)
bull.build()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\bullseye\lib\site-packages\tensorflow\python\framework\tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape)
#     526     try:
# --> 527       str_values = [compat.as_bytes(x) for x in proto_values]
#     528     except TypeError:
#
# C:\ProgramData\Anaconda3\envs\bullseye\lib\site-packages\tensorflow\python\framework\tensor_util.py in <listcomp>(.0)
#     526     try:
# --> 527       str_values = [compat.as_bytes(x) for x in proto_values]
#     528     except TypeError:
#
# C:\ProgramData\Anaconda3\envs\bullseye\lib\site-packages\tensorflow\python\util\compat.py in as_bytes(bytes_or_text, encoding)
#      60     raise TypeError('Expected binary or unicode string, got %r' %
# ---> 61                     (bytes_or_text,))
#      62
#
# ...

# %%
#r = bull.run(n_iter = 50)
r = bull.run_test()
# Out:
# 10
# inf
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\bullseye\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1277     try:
# -> 1278       return fn(*args)
#    1279     except errors.OpError as e:
#
# C:\ProgramData\Anaconda3\envs\bullseye\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1262       return self._call_tf_sessionrun(
# -> 1263           options, feed_dict, fetch_list, target_list, run_metadata)
#    1264
#
# C:\ProgramData\Anaconda3\envs\bullseye\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1349         self._session, options, feed_dict, fetch_list, target_list,
# -> 1350         run_metadata)
#    1351
#
# ...
